# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !pip install visualkeras
# Out:
# ...
#      |████████████████████████████████| 992 kB 5.8 MB/s
# ...

# %%
from keras.models import load_model
modelotf = load_model('/content/drive/Shareddrives/PovertyModels/Modelos/modeloFTL4_Rnet.h5',  compile=False)
weights1 = modelotf.get_weights()
#modelotf.summary()

# %%
# Ejemplos de estadistica descriptiva con python
import numpy as np # importando numpy
from scipy import stats # importando scipy.stats
import pandas as pd # importando pandas
df = weights1

# %%
keras.utils.plot_model(modelotf, "ResNet50model1.png")

# %% [markdown]
# #Visualizando representaciones intermedias

# %%
import visualkeras

model = modelotf

visualkeras.layered_view(model).show() # display using your system viewer
visualkeras.layered_view(model, to_file='output.png') # write to disk
visualkeras.layered_view(model, to_file='output.png').show() # write and show

visualkeras.layered_view(model)
# Out:
# <PIL.Image.Image image mode=RGBA size=12106x1227 at 0x7F7500CDFF10>

# %%
import numpy as np
import random
from   tensorflow.keras.preprocessing.image import img_to_array, load_img
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
from keras.preprocessing import image
import numpy as np
  
# Pre-processing the image
img = image.load_img('/content/ancoraimes1.jpg', target_size = (224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis = 0)
img_tensor = img_tensor / 255.
  
# Print image tensor shape
print(img_tensor.shape)
  
# Print image
import matplotlib.pyplot as plt
plt.imshow(img_tensor[0])
plt.show()
# Out:
# (1, 224, 224, 3)

# %%
# Outputs of the 8 layers, which include conv2D and max pooling layers
successive_outputs = [layer.output for layer in modelotf.layers[:260]]
visualization_model = tf.keras.models.Model(inputs = modelotf.input, outputs = successive_outputs)
activation_model = visualization_model
activations = activation_model.predict(img_tensor)

first_layer_activation1 = activations[2]
first_layer_activation2 = activations[3] 
first_layer_activation3 = activations[4]   
# Getting Activations of first layer
# shape of first layer activation
limit_up =181 
limit_lower=0
first_layer_activations = []
shape_first_layers = []

df_neuronas = []
count=0
layer_names = []


#for i in range(limit_lower, limit_up):
#  first_layer_activations.append(activations[i])
#  shape_first_layers.append(activations[i].shape)
#csv_covertion(shape_first_layers)

for first_layer_activation in first_layer_activations:
  #print(modelotf.layers[count].name)
  plt.matshow(first_layer_activation[0, :, :, 2], cmap ='nipy_spectral')
  count+=1 
  
for layer in modelotf.layers[limit_lower:limit_up]:
  layer_names.append(layer.name)
print(layer_names)

# 6th channel of the image after first layer of convolution is applied
plt.matshow(first_layer_activation1[0, :, :, 2], cmap ='nipy_spectral')
plt.matshow(first_layer_activation2[0, :, :, 2], cmap ='nipy_spectral')
plt.matshow(first_layer_activation3[0, :, :, 2], cmap ='nipy_spectral')
#plt.matshow(first_layer_activation[2, 2], cmap ='nipy_spectral')
# Out:
# ['input_1', 'conv1_pad', 'conv1_conv', 'conv1_bn', 'conv1_relu', 'pool1_pad', 'pool1_pool', 'conv2_block1_1_conv', 'conv2_block1_1_bn', 'conv2_block1_1_relu', 'conv2_block1_2_conv', 'conv2_block1_2_bn', 'conv2_block1_2_relu', 'conv2_block1_0_conv', 'conv2_block1_3_conv', 'conv2_block1_0_bn', 'conv2_block1_3_bn', 'conv2_block1_add', 'conv2_block1_out', 'conv2_block2_1_conv', 'conv2_block2_1_bn', 'conv2_block2_1_relu', 'conv2_block2_2_conv', 'conv2_block2_2_bn', 'conv2_block2_2_relu', 'conv2_block2_3_conv', 'conv2_block2_3_bn', 'conv2_block2_add', 'conv2_block2_out', 'conv2_block3_1_conv', 'conv2_block3_1_bn', 'conv2_block3_1_relu', 'conv2_block3_2_conv', 'conv2_block3_2_bn', 'conv2_block3_2_relu', 'conv2_block3_3_conv', 'conv2_block3_3_bn', 'conv2_block3_add', 'conv2_block3_out', 'conv3_block1_1_conv', 'conv3_block1_1_bn', 'conv3_block1_1_relu', 'conv3_block1_2_conv', 'conv3_block1_2_bn', 'conv3_block1_2_relu', 'conv3_block1_0_conv', 'conv3_block1_3_conv', 'conv3_block1_0_bn', 'conv3_
# ...

# %%
import csv
def csv_covertion(shape_first_layers): 

  headers = ('a', 'b', 'c','d')

  with open('layers.csv', 'w', newline='', encoding='utf-8') as csvfile:
      writer = csv.writer(csvfile)
      writer.writerow(headers)
      writer.writerows(shape_first_layers)

  with open('layers.csv') as csvfile:
      reader = csv.DictReader(csvfile)
      for row in reader:
          #print(row['b'])
# Out:
#   File "<ipython-input-12-2ffc0b7e8cca>", line 14
#     #print(row['b'])
#                     ^
# SyntaxError: unexpected EOF while parsing

# %%
import pandas as pd
df1=pd.read_csv('/content/weights.csv')
df1.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-d42dac3d06ad> in <module>()
#       1 import pandas as pd
# ----> 2 df1=pd.read_csv('/content/weights.csv')
#       3 df1.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...

# %%
headers = ('weights')

with open('weights.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(headers)
    writer.writerows(weights1)

with open('weights.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row['weights'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-52bb53f0947b> in <module>()
#       9     reader = csv.DictReader(csvfile)
#      10     for row in reader:
# ---> 11         print(row['weights'])
#
# KeyError: 'weights'

# %%
import pandas as pd 
df=pd.read_csv('/content/layers.csv')
df.head()
# Out:
#    a    b      c     d
# 0  1  224  224.0   3.0
# 1  1  230  230.0   3.0
# 2  1  112  112.0  64.0
# 3  1  112  112.0  64.0
# 4  1  112  112.0  64.0

# %%
df.describe()
# Out:
#            a              b           c            d
# count  181.0     181.000000  175.000000   175.000000
# mean     1.0     585.011050   28.685714   520.445714
# std      0.0    7456.893986   30.308539   545.533079
# min      1.0       3.000000    7.000000     3.000000
# 25%      1.0      14.000000   14.000000   128.000000
# 50%      1.0      14.000000   14.000000   256.000000
# 75%      1.0      28.000000   28.000000   512.000000
# max      1.0  100352.000000  230.000000  2048.000000

# %%
df.c.mode()
# Out:
# 0    14.0
# dtype: float64

# %%
new_df=df.assign(pesos=weights1)
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-518159f18bcd> in <module>()
# ----> 1 new_df=df.assign(pesos=weights1)
#       2 new_df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in assign(self, **kwargs)
#    3697
#    3698         for k, v in kwargs.items():
# -> 3699             data[k] = com.apply_if_callable(v, data)
#    3700         return data
#    3701
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# ...

# %%
layer_names = []
  
for layer in modelotf.layers[3:7]:
  layer_names.append(layer.name)
print(layer_names)
# Out:
# ['conv1_bn', 'conv1_relu', 'pool1_pad', 'pool1_pool']

# %%
successive_outputs = [layer.output for layer in modelotf.layers[178:180]]
visualization_model = tf.keras.models.Model(inputs = modelotf.input, outputs = successive_outputs)

# %%
img = load_img('/content/LaPaz_1.jpg', target_size=(224, 224))
x= img_to_array(img) 
x= x.reshape((1,) + x.shape) 
x /= 255.0
successive_feature_maps = visualization_model.predict(x)
layer_names = [layer.name for layer in modelotf.layers]
for layer_name, feature_map in zip(layer_names, successive_feature_maps):

  if len(feature_map.shape) == 4: 
     
    #-------------------------------------------
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    #-------------------------------------------
    n_features = feature_map.shape[-1]  # number of features in the feature map
    size       = feature_map.shape[ 1]  # feature map shape (1, size, size, n_features)
    
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    
    #-------------------------------------------------
    # Postprocess the feature to be visually palatable
    #-------------------------------------------------
    for i in range(n_features):
      x  = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std ()
      x *=  64
      x += 128
      x  = np.clip(x, 0, 255).astype('uint8')
      display_grid[:, i * size : (i + 1) * size] = x # Tile each filter into a horizontal grid

    #-----------------
    # Display the grid
    #-----------------

    scale = 20./ n_features
    #scale =1
    plt.figure( figsize=(scale * n_features, scale) )
    plt.title ( layer_name )
    plt.grid  ( False )
    plt.imshow( display_grid, aspect='auto', cmap='nipy_spectral' )
    #print(n_features)

# %%
print (n_features)
# Out:
# 2048

# %%
import zipfile
from google.colab import drive

drive.mount('/content/drive/')

zip_ref = zipfile.ZipFile("/content/drive/Shareddrives/PovertyModels/data/DataSet4.zip", 'r')
zip_ref.extractall("/tmp")
zip_ref.close()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import numpy as np
longitud, altura = 224, 224
cnn = modelotf
def predict(file):

  #for i, img_path in enumerate(next_cat_pix+next_dog_pix): 
  x = load_img(file, target_size=(longitud, altura))
  x = img_to_array(x)
  x = np.expand_dims(x, axis=0)
  array = cnn.predict(x)
  result = array[0]
  answer = np.argmax(result)
  #print(cnn.predict(x))
  #if answer == 0:
    #print("pred: nbi")
  #elif answer == 1:
    #print("pred: nbs")


  return answer

# %%
predict('/tmp/Dev/1/111MLP.jpg')
# Out:
# 1

# %%
from matplotlib import pyplot
feature_maps =predict('/tmp/Dev/1/111MLP.jpg')
square = 8
ix = 1

for _ in range(square):
	for _ in range(square):
		# specify subplot and turn of axis
		ax = pyplot.subplot(square, square, ix)
		ax.set_xticks([])
		ax.set_yticks([])
		# plot filter channel in grayscale
		pyplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
		ix += 1
# show the figure
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-a57fa7ed175d> in <module>()
#      10                 ax.set_yticks([])
#      11                 # plot filter channel in grayscale
# ---> 12                 pyplot.imshow(feature_maps[0, :, :, ix-1], cmap='gray')
#      13                 ix += 1
#      14 # show the figure
#
# IndexError: invalid index to scalar variable.

# %%
img =load_img('/tmp/Dev/1/111MLP.jpg', target_size=(224, 224))
img = img_to_array(img)
img = preprocess_input(img)
feature_maps = modelotf.predict(img)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a06a7166a6c6> in <module>()
#       2 img = img_to_array(img)
#       3 img = preprocess_input(img)
# ----> 4 feature_maps = modelotf.predict(img)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
# ...
